# %%
# %matplotlib inline
# Out:
# /home/agnosticdev/Documents/code/python/jupyter_notebook/notebooks/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 8)
plt.plot([4, 10, 24.46, 48.93, 79.51, 154.26, 307.42, 614.63], 'r')
plt.title('Taylor Expansion Series e^3');
